# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
sales = pd.read_csv('Sales.csv', sep=",", encoding="ISO-8859-1", header=0)

# %%
sales.head()
# Out:
#         outlet_id  transaction_time expected_rainfall         freezer_status  \
# 0  outlet_code_78  2023-01-05 12:41              25mm    freezers available
# 1  outlet_code_78  2023-01-12 13:05               0mm    freezers available
# 2  outlet_code_78   2023-01-17 9:32              79mm    freezers available
# 3  outlet_code_78  2023-01-27 14:21          194.51mm    freezers available
# 4  outlet_code_78  2023-01-31 16:24              15mm    freezers available
#
#              sku_name  sales_quantity
# 0  Sweet Delights Mix             3.0
# 1  Sweet Delights Mix             3.0
# 2  Sweet Delights Mix             3.0
# 3  Sweet Delights Mix             2.0
# 4  Sweet Delights Mix             3.0

# %%
outlet_df = pd.read_csv('Outlet Info.csv', sep=",", encoding="ISO-8859-1", header=0)
outlet_df.head()
# Out:
#        outlet_id      region  outlet_size  population_density  \
# 0  outlet_code_1  outstation         1334                 276
# 1  outlet_code_2  outstation         1336                 276
# 2  outlet_code_3  outstation         1341                 277
# 3  outlet_code_4  outstation         1025                 239
# 4  outlet_code_5   upcountry         3965                 646
#
#    number_of_skus_sold  average_household_income
# 0                   16                     81704
# 1                   16                     81789
# 2                   16                     82046
# 3                   13                     66259
# 4                   35                     59469

# %%
mapping = pd.read_csv("Distributor Outlet Mapping.csv")

# %%
mapping.head()
# Out:
#    distributor_id      outlet_id
# 0  distributor_24  outlet_code_1
# 1  distributor_24  outlet_code_2
# 2  distributor_24  outlet_code_3
# 3   distributor_3  outlet_code_4
# 4  distributor_21  outlet_code_5

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137348 entries, 0 to 137347
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   outlet_id          137348 non-null  object
#  1   transaction_time   137348 non-null  object
#  2   expected_rainfall  137348 non-null  object
#  3   freezer_status     137348 non-null  object
#  4   sku_name           137347 non-null  object
#  5   sales_quantity     137347 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 6.3+ MB

# %%
outlet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4200 entries, 0 to 4199
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   outlet_id                 4200 non-null   object
#  1   region                    4200 non-null   object
#  2   outlet_size               4200 non-null   int64
#  3   population_density        4200 non-null   int64
#  4   number_of_skus_sold       4200 non-null   int64
#  5   average_household_income  4200 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 197.0+ KB

# %%
sales[sales["outlet_id"] == "outlet_code_1"]
# Out:
#            outlet_id  transaction_time expected_rainfall  \
# 41348  outlet_code_1  2023-01-06 10:51              60mm
# 41349  outlet_code_1  2023-01-12 15:14               6mm
# 41350  outlet_code_1  2023-01-16 16:25              82mm
# 41351  outlet_code_1   2023-01-24 8:55          172.53mm
# 41352  outlet_code_1   2023-02-04 9:53              59mm
# 41353  outlet_code_1  2023-02-10 10:01              15mm
# 41354  outlet_code_1  2023-02-18 12:09              33mm
# 41355  outlet_code_1  2023-02-23 16:16               4mm
# 41356  outlet_code_1   2023-03-02 9:50          178.29mm
# 41357  outlet_code_1  2023-03-08 12:49               3mm
# 41358  outlet_code_1  2023-03-16 15:27              57mm
# 41359  outlet_code_1  2023-03-24 16:43          179.54mm
# 41360  outlet_code_1  2023-03-29 16:26              28mm
# 41361  outlet_code_1  2023-04-08 15:35              50mm
# 41362  outlet_code_1   2023-04-13 9:47              48mm
# 41363  outlet_code_1  2023-04-17 16:02          164.57mm
# 41364  outlet_code_1  2023-04-29 12:59              86mm
# 41365  outlet_code_1  2023-05-02 11:38              32mm
# 41366  outlet_code_1  2023-05-13 13:24          186.24mm
# 41367  outlet_code_1  2023-05-19 14:50              46mm
# 41368  outlet_code_1  2023-05-22 10:24               6mm
# 41369  outlet_code_1  2023-05-31 12:45              28mm
#
#              freezer_status           sku_name  sales_quantity
# 41348   freezers available   Fruit Chewy Bites             4.0
# 41349   freezers available   Fruit Chewy Bites             5.0
# 41350   freezers available   Fruit Chewy Bites             5.0
# 41351   freezers available   Fruit Chewy Bites             7.0
# 41352   freezers available   Fruit Chewy Bites             5.0
# 41353   freezers available   Fruit Chewy Bites            10.0
# 41354   freezers available   Fruit Chewy Bites             7.0
# 41355   freezers available   Fruit Chewy Bites             7.0
# 41356   freezers available   Fruit Chewy Bites             7.0
# 41357   freezers available   Fruit Chewy Bites            10.0
# 41358   freezers available   Fruit Chewy Bites             6.0
# 41359   freezers available   Fruit Chewy Bites             6.0
# 41360   freezers available   Fruit Chewy Bites            12.0
# 41361   freezers available   Fruit Chewy Bites            12.0
# 41362   freezers available   Fruit Chewy Bites             7.0
# 41363   freezers available   Fruit Chewy Bites             6.0
# 41364   freezers available   Fruit Chewy Bites            13.0
# 41365   freezers available   Fruit Chewy Bites            13.0
# 41366   freezers available   Fruit Chewy Bites             6.0
# 41367   freezers available   Fruit Chewy Bites            11.0
# 41368   freezers available   Fruit Chewy Bites             8.0
# 41369   freezers available   Fruit Chewy Bites            13.0

# %%
merged_df = pd.merge(sales, outlet_df, on="outlet_id")

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137348 entries, 0 to 137347
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   outlet_id                 137348 non-null  object
#  1   transaction_time          137348 non-null  object
#  2   expected_rainfall         137348 non-null  object
#  3   freezer_status            137348 non-null  object
#  4   sku_name                  137347 non-null  object
#  5   sales_quantity            137347 non-null  float64
#  6   region                    137348 non-null  object
#  7   outlet_size               137348 non-null  int64
#  8   population_density        137348 non-null  int64
#  9   number_of_skus_sold       137348 non-null  int64
#  10  average_household_income  137348 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 12.6+ MB

# %%
merged_df.to_csv("output_file.csv",index=False, encoding="ISO-8859-1")

# %%
df = pd.read_csv("output_file.csv")

# %%
df.head(6)
# Out:
#         outlet_id  transaction_time expected_rainfall         freezer_status  \
# 0  outlet_code_78  2023-01-05 12:41              25mm    freezers available
# 1  outlet_code_78  2023-01-12 13:05               0mm    freezers available
# 2  outlet_code_78   2023-01-17 9:32              79mm    freezers available
# 3  outlet_code_78  2023-01-27 14:21          194.51mm    freezers available
# 4  outlet_code_78  2023-01-31 16:24              15mm    freezers available
# 5  outlet_code_78  2023-02-08 12:44              94mm    freezers available
#
#              sku_name  sales_quantity      region  outlet_size  \
# 0  Sweet Delights Mix             3.0  outstation         2870
# 1  Sweet Delights Mix             3.0  outstation         2870
# 2  Sweet Delights Mix             3.0  outstation         2870
# 3  Sweet Delights Mix             2.0  outstation         2870
# 4  Sweet Delights Mix             3.0  outstation         2870
# 5  Sweet Delights Mix             3.0  outstation         2870
#
#    population_density  number_of_skus_sold  average_household_income
# 0                 344                   14                     71756
# 1                 344                   14                     71756
# 2                 344                   14                     71756
# 3                 344                   14                     71756
# 4                 344                   14                     71756
# 5                 344                   14                     71756

# %%
df.tail()
# Out:
#                outlet_id  transaction_time expected_rainfall  \
# 137343  outlet_code_3057  2023-04-28 13:16              32mm
# 137344  outlet_code_3057   2023-05-01 9:51              59mm
# 137345  outlet_code_3057  2023-05-09 16:39           81.02mm
# 137346  outlet_code_3057   2023-05-18 9:03               4mm
# 137347  outlet_code_3057  2023-05-24 14:41              43mm
#
#               freezer_status           sku_name  sales_quantity   region  \
# 137343   freezers available   Fruit Chewy Bites            16.0  western
# 137344   freezers available   Fruit Chewy Bites            19.0  western
# 137345   freezers available   Fruit Chewy Bites            16.0  western
# 137346   freezers available   Fruit Chewy Bites            15.0  western
# 137347   freezers available   Fruit Chewy Bites            24.0  western
#
#         outlet_size  population_density  number_of_skus_sold  \
# 137343         1133                2066                   35
# 137344         1133                2066                   35
# 137345         1133                2066                   35
# 137346         1133                2066                   35
# 137347         1133                2066                   35
#
#         average_household_income
# 137343                    118301
# 137344                    118301
# 137345                    118301
# 137346                    118301
# 137347                    118301

# %%
df.shape
# Out:
# (137348, 11)

# %%
df.nunique()
# Out:
# outlet_id                    4200
# transaction_time            62092
# expected_rainfall            9704
# freezer_status                  4
# sku_name                        4
# sales_quantity                 66
# region                          3
# outlet_size                  1640
# population_density           1559
# number_of_skus_sold            51
# average_household_income     4125
# dtype: int64

# %%
df["expected_rainfall_num"] = pd.to_numeric(df["expected_rainfall"].str.replace("mm", ""), errors="coerce")

# %%
df.corr()
# Out:
# <ipython-input-28-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           sales_quantity  outlet_size  population_density  \
# sales_quantity                  1.000000     0.376421            0.426136
# outlet_size                     0.376421     1.000000            0.259453
# population_density              0.426136     0.259453            1.000000
# number_of_skus_sold             0.359745     0.220011            0.906953
# average_household_income        0.308166     0.189437            0.806620
# expected_rainfall_num          -0.088617    -0.006649           -0.141811
#
#                           number_of_skus_sold  average_household_income  \
# sales_quantity                       0.359745                  0.308166
# outlet_size                          0.220011                  0.189437
# population_density                   0.906953                  0.806620
# number_of_skus_sold                  1.000000                  0.837900
# average_household_income             0.837900                  1.000000
# expected_rainfall_num               -0.130893                 -0.122101
#
#                           expected_rainfall_num
# sales_quantity                        -0.088617
# outlet_size                           -0.006649
# population_density                    -0.141811
# number_of_skus_sold                   -0.130893
# average_household_income              -0.122101
# expected_rainfall_num                  1.000000

# %%
def clean_freezer(df: pd.DataFrame) -> pd.DataFrame:
    unique_values = np.unique(df["freezer_status"])
    values = np.array(unique_values, dtype=str)

    replacement_dict = {value: 'freezers available' for value in values if value.strip() == 'freezers available'}
    replacement_dict_2 = {'freezers available': 1, ' nofreezers available': 0}

    df["freezer_status"] = df["freezer_status"].replace(replacement_dict, regex=True)

    df["freezer_status"] = df["freezer_status"].replace(replacement_dict_2)

    return df

df = clean_freezer(df)
df.corr()
# Out:
# <ipython-input-29-8972a620afb8>:15: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           freezer_status  sales_quantity  outlet_size  \
# freezer_status                  1.000000        0.452458     0.625314
# sales_quantity                  0.452458        1.000000     0.376421
# outlet_size                     0.625314        0.376421     1.000000
# population_density              0.127867        0.426136     0.259453
# number_of_skus_sold             0.111072        0.359745     0.220011
# average_household_income        0.001667        0.308166     0.189437
# expected_rainfall_num          -0.011928       -0.088617    -0.006649
#
#                           population_density  number_of_skus_sold  \
# freezer_status                      0.127867             0.111072
# sales_quantity                      0.426136             0.359745
# outlet_size                         0.259453             0.220011
# population_density                  1.000000             0.906953
# number_of_skus_sold                 0.906953             1.000000
# average_household_income            0.806620             0.837900
# expected_rainfall_num              -0.141811            -0.130893
#
#                           average_household_income  expected_rainfall_num
# freezer_status                            0.001667              -0.011928
# sales_quantity                            0.308166              -0.088617
# outlet_size                               0.189437              -0.006649
# population_density                        0.806620              -0.141811
# number_of_skus_sold                       0.837900              -0.130893
# average_household_income                  1.000000              -0.122101
# expected_rainfall_num                    -0.122101               1.000000

# %%
def clean_outlet_region(df: pd.DataFrame) -> pd.DataFrame:
    encoded = pd.get_dummies(df['region'], prefix='region')
    df = pd.concat([df, encoded], axis=1)
    df = df.drop(columns=['region'])
    df = df.replace({True: 1, False: 0})

    return df

df = clean_outlet_region(df)

# %%
def convert_to_date(df: pd.DataFrame):

    df["transaction_time"] = pd.to_datetime(df["transaction_time"], format='%Y-%m-%d %H:%M', errors='coerce')

    # If you want to extract the week number
    df["transaction_time"] = df["transaction_time"].dt.isocalendar().week.astype("int")

    return df

df = convert_to_date(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137348 entries, 0 to 137347
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   outlet_id                 137348 non-null  object
#  1   transaction_time          137348 non-null  int64
#  2   expected_rainfall         137348 non-null  object
#  3   freezer_status            137348 non-null  int64
#  4   sku_name                  137347 non-null  object
#  5   sales_quantity            137347 non-null  float64
#  6   outlet_size               137348 non-null  int64
#  7   population_density        137348 non-null  int64
#  8   number_of_skus_sold       137348 non-null  int64
#  9   average_household_income  137348 non-null  int64
#  10  expected_rainfall_num     137348 non-null  float64
#  11  region_outstation         137348 non-null  uint8
#  12  region_upcountry          137348 non-null  uint8
#  13  region_western            137348 non-null  uint8
# dtypes: float64(2), int64(6), object(3), uint8(3)
# memory usage: 11.9+ MB

# %%
df.head()
# Out:
#         outlet_id  transaction_time expected_rainfall  freezer_status  \
# 0  outlet_code_78                 1              25mm               1
# 1  outlet_code_78                 2               0mm               1
# 2  outlet_code_78                 3              79mm               1
# 3  outlet_code_78                 4          194.51mm               1
# 4  outlet_code_78                 5              15mm               1
#
#              sku_name  sales_quantity  outlet_size  population_density  \
# 0  Sweet Delights Mix             3.0         2870                 344
# 1  Sweet Delights Mix             3.0         2870                 344
# 2  Sweet Delights Mix             3.0         2870                 344
# 3  Sweet Delights Mix             2.0         2870                 344
# 4  Sweet Delights Mix             3.0         2870                 344
#
#    number_of_skus_sold  average_household_income  expected_rainfall_num  \
# 0                   14                     71756                  25.00
# 1                   14                     71756                   0.00
# 2                   14                     71756                  79.00
# 3                   14                     71756                 194.51
# 4                   14                     71756                  15.00
#
#    region_outstation  region_upcountry  region_western
# 0                  1                 0               0
# 1                  1                 0               0
# 2                  1                 0               0
# 3                  1                 0               0
# 4                  1                 0               0

# %%
df.nunique()
# Out:
# outlet_id                   4200
# transaction_time              22
# expected_rainfall           9704
# freezer_status                 2
# sku_name                       4
# sales_quantity                66
# outlet_size                 1640
# population_density          1559
# number_of_skus_sold           51
# average_household_income    4125
# expected_rainfall_num       9693
# region_outstation              2
# region_upcountry               2
# region_western                 2
# dtype: int64

# %%
def sort_dataframe(df, column_name)-> pd.DataFrame:
    sorted_df = df.sort_values(by=[column_name])
    return sorted_df

df = sort_dataframe(df,"transaction_time")

# %%
df.head()
# Out:
#               outlet_id  transaction_time expected_rainfall  freezer_status  \
# 0        outlet_code_78                 1              25mm               1
# 12478  outlet_code_4060                 1              56mm               1
# 79292  outlet_code_4070                 1              50mm               1
# 46059  outlet_code_2949                 1              48mm               0
# 29231   outlet_code_698                 1              24mm               1
#
#                         sku_name  sales_quantity  outlet_size  \
# 0             Sweet Delights Mix             3.0         2870
# 12478          Fruit Chewy Bites            14.0         3986
# 79292          Fruit Chewy Bites             3.0         1547
# 46059  Gummy Carnival Assortment             2.0          357
# 29231          Fruit Chewy Bites            18.0         2798
#
#        population_density  number_of_skus_sold  average_household_income  \
# 0                     344                   14                     71756
# 12478                 399                   20                     99655
# 79292                 302                   18                     92360
# 46059                 139                   18                     89280
# 29231                3397                   36                    114924
#
#        expected_rainfall_num  region_outstation  region_upcountry  \
# 0                       25.0                  1                 0
# 12478                   56.0                  1                 0
# 79292                   50.0                  1                 0
# 46059                   48.0                  1                 0
# 29231                   24.0                  0                 0
#
#        region_western
# 0                   0
# 12478               0
# 79292               0
# 46059               0
# 29231               1

# %%
def drop_columns(df: pd.DataFrame, columns_to_drop):
    # Create a new DataFrame without the specified columns
    new_df = df.drop(columns=columns_to_drop, errors='ignore')
    return new_df

columns_to_drop = ["outlet_id", "expected_rainfall", "sku_name"]

cleaned_df = drop_columns(df, columns_to_drop)

# %%
cleaned_df.to_csv("cleaned_data.csv",index=False, encoding="ISO-8859-1")

# %%
df.to_csv("without_drop_column.csv",index=False, encoding="ISO-8859-1")
df = pd.read_csv("without_drop_column.csv")
df
# Out:
#                outlet_id  transaction_time expected_rainfall  freezer_status  \
# 0         outlet_code_78                 1              25mm               1
# 1       outlet_code_4060                 1              56mm               1
# 2       outlet_code_4070                 1              50mm               1
# 3       outlet_code_2949                 1              48mm               0
# 4        outlet_code_698                 1              24mm               1
# ...                  ...               ...               ...             ...
# 137343   outlet_code_445                22              56mm               1
# 137344   outlet_code_983                22              51mm               1
# 137345   outlet_code_920                22              77mm               1
# 137346  outlet_code_1962                22              86mm               0
# 137347  outlet_code_3994                22               7mm               1
#
#                          sku_name  sales_quantity  outlet_size  \
# 0              Sweet Delights Mix             3.0         2870
# 1               Fruit Chewy Bites            14.0         3986
# 2               Fruit Chewy Bites             3.0         1547
# 3       Gummy Carnival Assortment             2.0          357
# 4               Fruit Chewy Bites            18.0         2798
# ...                           ...             ...          ...
# 137343          Fruit Chewy Bites             5.0         1078
# 137344          Fruit Chewy Bites             8.0         1158
# 137345          Fruit Chewy Bites            15.0          845
# 137346          Fruit Chewy Bites             3.0          350
# 137347         Sweet Delights Mix             6.0         3247
#
#         population_density  number_of_skus_sold  average_household_income  \
# 0                      344                   14                     71756
# 1                      399                   20                     99655
# 2                      302                   18                     92360
# 3                      139                   18                     89280
# 4                     3397                   36                    114924
# ...                    ...                  ...                       ...
# 137343                 245                   14                     68895
# 137344                 255                   15                     72876
# 137345                 217                   11                     57227
# 137346                 138                   18                     87590
# 137347                 575                   26                     48705
#
#         expected_rainfall_num  region_outstation  region_upcountry  \
# 0                        25.0                  1                 0
# 1                        56.0                  1                 0
# 2                        50.0                  1                 0
# 3                        48.0                  1                 0
# 4                        24.0                  0                 0
# ...                       ...                ...               ...
# 137343                   56.0                  1                 0
# 137344                   51.0                  1                 0
# 137345                   77.0                  1                 0
# 137346                   86.0                  1                 0
# 137347                    7.0                  0                 1
#
#         region_western
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1
# ...                ...
# 137343               0
# 137344               0
# 137345               0
# 137346               0
# 137347               0
#
# [137348 rows x 14 columns]

# %%
import matplotlib.pyplot as plt

# %%
boxplot=df.boxplot(column=["sales_quantity","outlet_size","population_density","number_of_skus_sold","average_household_income","transaction_time","freezer_status","expected_rainfall_num","region_outstation","region_upcountry","region_western"])

# %%
df.quantile(0.25)
# Out:
# <ipython-input-46-29e18f3a7353>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.25)
# transaction_time                6.0
# freezer_status                  0.0
# sales_quantity                  3.0
# outlet_size                   395.0
# population_density            255.0
# number_of_skus_sold            14.0
# average_household_income    55320.0
# expected_rainfall_num          28.0
# region_outstation               0.0
# region_upcountry                0.0
# region_western                  0.0
# Name: 0.25, dtype: float64

# %%
df.quantile(0.75)
# Out:
# <ipython-input-47-396ba156e02a>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.75)
# transaction_time               17.0
# freezer_status                  1.0
# sales_quantity                 10.0
# outlet_size                  1691.0
# population_density           1334.0
# number_of_skus_sold            27.0
# average_household_income    96300.0
# expected_rainfall_num          90.0
# region_outstation               1.0
# region_upcountry                0.0
# region_western                  1.0
# Name: 0.75, dtype: float64

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)

filtered_entries = ~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR)))
clean_data = df[filtered_entries]
clean_data
# Out:
# transaction_time               11.0
# freezer_status                  1.0
# sales_quantity                  7.0
# outlet_size                  1296.0
# population_density           1079.0
# number_of_skus_sold            13.0
# average_household_income    40980.0
# expected_rainfall_num          62.0
# region_outstation               1.0
# region_upcountry                0.0
# region_western                  1.0
# dtype: float64
# <ipython-input-48-b5720c771195>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# <ipython-input-48-b5720c771195>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)
# <ipython-input-48-b5720c771195>:6: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   filtered_entries = ~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR)))
#                outlet_id  transaction_time expected_rainfall  freezer_status  \
# 0         outlet_code_78                 1              25mm               1
# 1       outlet_code_4060                 1              56mm               1
# 2       outlet_code_4070                 1              50mm               1
# 3       outlet_code_2949                 1              48mm               0
# 4        outlet_code_698                 1              24mm               1
# ...                  ...               ...               ...             ...
# 137343   outlet_code_445                22              56mm               1
# 137344   outlet_code_983                22              51mm               1
# 137345   outlet_code_920                22              77mm               1
# 137346  outlet_code_1962                22              86mm               0
# 137347  outlet_code_3994                22               7mm               1
#
#                          sku_name  sales_quantity  outlet_size  \
# 0              Sweet Delights Mix             3.0       2870.0
# 1               Fruit Chewy Bites            14.0          NaN
# 2               Fruit Chewy Bites             3.0       1547.0
# 3       Gummy Carnival Assortment             2.0        357.0
# 4               Fruit Chewy Bites            18.0       2798.0
# ...                           ...             ...          ...
# 137343          Fruit Chewy Bites             5.0       1078.0
# 137344          Fruit Chewy Bites             8.0       1158.0
# 137345          Fruit Chewy Bites            15.0        845.0
# 137346          Fruit Chewy Bites             3.0        350.0
# 137347         Sweet Delights Mix             6.0       3247.0
#
#         population_density  number_of_skus_sold  average_household_income  \
# 0                    344.0                 14.0                   71756.0
# 1                    399.0                 20.0                   99655.0
# 2                    302.0                 18.0                   92360.0
# 3                    139.0                 18.0                   89280.0
# 4                      NaN                 36.0                  114924.0
# ...                    ...                  ...                       ...
# 137343               245.0                 14.0                   68895.0
# 137344               255.0                 15.0                   72876.0
# 137345               217.0                 11.0                   57227.0
# 137346               138.0                 18.0                   87590.0
# 137347               575.0                 26.0                   48705.0
#
#         expected_rainfall_num  region_outstation  region_upcountry  \
# 0                        25.0                  1               0.0
# 1                        56.0                  1               0.0
# 2                        50.0                  1               0.0
# 3                        48.0                  1               0.0
# 4                        24.0                  0               0.0
# ...                       ...                ...               ...
# 137343                   56.0                  1               0.0
# 137344                   51.0                  1               0.0
# 137345                   77.0                  1               0.0
# 137346                   86.0                  1               0.0
# 137347                    7.0                  0               NaN
#
#         region_western
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1
# ...                ...
# 137343               0
# 137344               0
# 137345               0
# 137346               0
# 137347               0
#
# [137348 rows x 14 columns]
